# %%
import pyvisa
import json
import time
import os
import numpy as np
from datetime import datetime

# %%
rm = pyvisa.ResourceManager()
rm.list_resources()
# Out:
# ('ASRL3::INSTR', 'ASRL4::INSTR', 'GPIB0::15::INSTR')

# %%
tc = rm.open_resource('GPIB0::15::INSTR') #temperature controller instance

# %%
tc.query('*IDN?')
# Out:
# 'LSCI,MODEL331S,331162,121300\r\n'

# %%
state = {}
state['A'] = float(tc.query('KRDG? A'))
state['B'] = float(tc.query('KRDG? B'))
state['datetime'] = datetime.today().strftime('%Y-%m-%d %H:%M:%S')
state
# Out:
# {'A': 294.37, 'B': 294.21, 'datetime': '2026-02-27 08:38:11'}

# %%
seconds_per_point = 10 
number_of_points = 1000
for index in range(number_of_points):
    state = {}
    state['A'] = float(tc.query('KRDG? A'))
    state['B'] = float(tc.query('KRDG? B'))
    state['datetime'] = datetime.today().strftime('%Y-%m-%d %H:%M:%S')
    print(json.dumps(state))
    log.append(state)
    file_object = open("temperature.json", "w")
    file_object.write(json.dumps(state))
    file_object.close()
    time.sleep(seconds_per_point)
# Out:
# {"A": 294.37, "B": 294.21, "datetime": "2026-02-27 08:40:48"}
# {"A": 294.36, "B": 294.21, "datetime": "2026-02-27 08:40:58"}
# {"A": 294.36, "B": 294.21, "datetime": "2026-02-27 08:41:08"}
# {"A": 294.37, "B": 294.21, "datetime": "2026-02-27 08:41:18"}
# {"A": 294.37, "B": 294.21, "datetime": "2026-02-27 08:41:28"}
# {"A": 294.37, "B": 294.21, "datetime": "2026-02-27 08:41:38"}
# {"A": 294.37, "B": 294.21, "datetime": "2026-02-27 08:41:48"}
# {"A": 294.37, "B": 294.21, "datetime": "2026-02-27 08:41:58"}
# {"A": 294.37, "B": 294.21, "datetime": "2026-02-27 08:42:08"}
# {"A": 294.37, "B": 294.21, "datetime": "2026-02-27 08:42:18"}
# {"A": 294.36, "B": 294.21, "datetime": "2026-02-27 08:42:28"}
# {"A": 294.37, "B": 294.21, "datetime": "2026-02-27 08:42:38"}
# {"A": 294.37, "B": 294.21, "datetime": "2026-02-27 08:42:48"}
# {"A": 294.37, "B": 294.21, "datetime": "2026-02-27 08:42:58"}
# {"A": 294.37, "B": 294.21, "datetime": "2026-02-27 08:43:08"}
# {"A": 294.36, "B": 294.21, "datetime": "2026-02-27 08:43:18"}
# {"A": 294.37, "B": 294.21, "datetime": "2026-02-27 08:43:28"}
# {"A": 294.37, "B": 294.21, "datetime": "2026-02-27 08:43:38"}
