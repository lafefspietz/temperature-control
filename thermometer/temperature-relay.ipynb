# %%
import urllib3
import json

# %%
thermometer = urllib3.request("GET", "http://672062138lab2.campus.nist.gov/temperature-control/temperature.json")
temperaturestring = thermometer.data.decode()
urllib3.request("GET", "https://fluxquantum.art/thermotron/remote-save.php?filename=temperature.json&data=" + temperaturestring)

# %%
cloud = urllib3.request("GET", "https://fluxquantum.art/thermotron/temperature.json")
cloud.data.decode()
# Out:
# '{"A": 294.37, "B": 294.21, "datetime": "2026-02-27 09:04:50"}'
